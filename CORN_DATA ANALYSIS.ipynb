# %%
import pandas as pd
data = pd.read_csv("corn_productionTexas.csv", delimiter = ",",header = 0,names = ["Ag Distric", "Ag Code",'County',"CORN, GRAIN - Production, MEASURED IN BU 2020" ,'CORN, GRAIN - Production, MEASURED IN BU 2021'],index_col=0)

# %%
production = data.loc[["NORTHERN HIGH PLAINS",'SOUTHERN HIGH PLAINS'],['County','CORN, GRAIN - Production, MEASURED IN BU 2020','CORN, GRAIN - Production, MEASURED IN BU 2021']]
production
# Out:
#                           County  \
# Ag Distric
# NORTHERN HIGH PLAINS      CARSON
# NORTHERN HIGH PLAINS      DALLAM
# NORTHERN HIGH PLAINS  DEAF SMITH
# NORTHERN HIGH PLAINS        GRAY
# NORTHERN HIGH PLAINS        HALE
# NORTHERN HIGH PLAINS    HANSFORD
# NORTHERN HIGH PLAINS     HARTLEY
# NORTHERN HIGH PLAINS  HUTCHINSON
# NORTHERN HIGH PLAINS    LIPSCOMB
# NORTHERN HIGH PLAINS       MOORE
# NORTHERN HIGH PLAINS   OCHILTREE
# NORTHERN HIGH PLAINS     SHERMAN
# NORTHERN HIGH PLAINS     SWISHER
# SOUTHERN HIGH PLAINS   GLASSCOCK
# SOUTHERN HIGH PLAINS     HOCKLEY
# SOUTHERN HIGH PLAINS        LAMB
# SOUTHERN HIGH PLAINS        LYNN
#
#                      CORN, GRAIN - Production, MEASURED IN BU 2020  \
# Ag Distric
# NORTHERN HIGH PLAINS                                           NaN
# NORTHERN HIGH PLAINS                                    14,855,000
# NORTHERN HIGH PLAINS                                     4,423,000
# ...

# %%
production_totals = production.iloc[]
#production_totals.iloc[0:16,[0]].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/aylingracia/Desktop/USDA DATA/CORN_DATA ANALYSIS.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/aylingracia/Desktop/USDA%20DATA/CORN_DATA%20ANALYSIS.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> production_totals = production.iloc[:,[1]]
#
# NameError: name 'production' is not defined
